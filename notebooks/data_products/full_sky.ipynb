# %%
import h5py
import os
import matplotlib.pyplot as plt

# %%
grid_dir = "/global/cfs/cdirs/des/cosmogrid/DESY3/grid"
fid_dir = "/global/cfs/cdirs/des/cosmogrid/DESY3/fiducial"

# %%
perm_dir = "/global/cfs/cdirs/des/cosmogrid/DESY3/grid/cosmo_003206/perm_0002"
map_file = "projected_probes_maps_nobaryons512.h5"

with h5py.File(os.path.join(perm_dir, map_file), "r") as f:
    kappa = f["kg/desy3metacal2"][:]
    # print(f["kg/desy3metacal1"].keys())

# %%
plt.hist(kappa, bins=50)

print(kappa.min())
print(kappa.max())
# Out:
# 0.011649047
# 0.20267357
