# %%
from msfm.utils import logging
import time

# %%
LOGGER = logging.get_logger("Arne")

# %%
LOGGER.info("test")
# Out:
# 23-01-04 16:36:19         Arne INF   test

# %%
for i in LOGGER.progressbar(range(10), desc='testing logger', at_level='info'):
    time.sleep(1)
    LOGGER.info(i)
# Out:
#   0%|                            |   | 0/10 [00:00<?, ?it/s]                  testing logger23-01-04 16:36:20         Arne INF   0
#  10%|██▊                         |   | 1/10 [00:01<00:09,  1.00s/it]          testing logger23-01-04 16:36:21         Arne INF   1
#  20%|█████▌                      |   | 2/10 [00:02<00:08,  1.00s/it]          testing logger23-01-04 16:36:22         Arne INF   2
#  30%|████████▍                   |   | 3/10 [00:03<00:07,  1.00s/it]          testing logger23-01-04 16:36:23         Arne INF   3
#  40%|███████████▏                |   | 4/10 [00:04<00:06,  1.00s/it]          testing logger23-01-04 16:36:24         Arne INF   4
#  50%|██████████████              |   | 5/10 [00:05<00:05,  1.00s/it]          testing logger23-01-04 16:36:25         Arne INF   5
#  60%|████████████████▊           |   | 6/10 [00:06<00:04,  1.00s/it]          testing logger23-01-04 16:36:26         Arne INF   6
# ...
