# %%
# %load_ext autoreload
# %autoreload 2

# %%
import h5py

import tensorflow as tf
tf.config.experimental.set_memory_growth(tf.config.list_physical_devices(device_type="GPU")[0], True)
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt
from tqdm import tqdm

from msfm.utils import tfrecords, files, parameters, cross_statistics
from msfm.fiducial_pipeline import FiducialPipeline
from msfm.grid_pipeline import GridPipeline
from msfm.utils.input_output import read_yaml

# %%
with_lensing = True
with_clustering = True

# %% [markdown]
# # grid

# %%
# tfr_pattern = "/pscratch/sd/a/athomsen/v11desy3/v10/debug/linear_bias/tfrecords/grid/DESy3_grid_dmb_0000.tfrecord"
tfr_pattern = "/pscratch/sd/a/athomsen/v11desy3/v10/linear_bias/tfrecords/grid/DESy3_grid_dmb_0000.tfrecord"

# conf = "/global/homes/a/athomsen/multiprobe-simulation-forward-model/configs/v10/linear_bias_debug.yaml"
conf = "/global/homes/a/athomsen/multiprobe-simulation-forward-model/configs/v10/linear_bias.yaml"
conf = files.load_config(conf)

params = ["Om", "s8", "Ob", "H0", "ns", "w0", "Aia", "n_Aia", "bg", "n_bg"]

# %%
grid_pipe = GridPipeline(
    conf=conf,
    params=params,
    with_lensing=with_lensing,
    with_clustering=with_clustering,
    with_padding=True,
    apply_norm=False,
    return_maps=True,
)

data_vec_pix = grid_pipe.data_vec_pix
n_side = conf["analysis"]["n_side"]
n_pix = hp.nside2npix(n_side)
n_z = grid_pipe.n_z_metacal + grid_pipe.n_z_maglim
n_z_metacal = grid_pipe.n_z_metacal
n_noise = conf["analysis"]["grid"]["n_noise_per_example"]
# n_noise = 1
# Out:
# 24-09-19 00:37:44     files.py INF   Loaded the pixel file /global/u2/a/athomsen/multiprobe-simulation-forward-model/data/DESY3_pixels_v11_fiducial_512.h5
# 24-09-19 00:37:44     files.py INF   Loaded the pixel file /global/u2/a/athomsen/multiprobe-simulation-forward-model/data/DESY3_pixels_v11_fiducial_512.h5

# %%
n_perms_per_cosmo = conf["analysis"]["grid"]["n_perms_per_cosmo"]
n_patches = conf["analysis"]["n_patches"]
n_signal = n_perms_per_cosmo * n_patches

batch_size = 1
n_batches = n_signal * n_noise // batch_size

# %%
grid_dset = grid_pipe.get_dset(
    tfr_pattern="/pscratch/sd/a/athomsen/v11desy3/v10/linear_bias/tfrecords/grid/DESy3_grid_dmb_0000.tfrecord",
    noise_indices=1,
    local_batch_size=1,
    n_readers=1,
    n_prefetch=0,
    is_eval=True,
)

i = 0
for dv, cl, cosmo, index in tqdm(grid_dset):
    i += 1
print(i)
# Out:
# 24-09-19 00:39:35 grid_pipelin INF   n_workers is not set, using tf.data.AUTOTUNE. This might produce unexpected RAM usage.
# 24-09-19 00:39:35 grid_pipelin INF   drop_remainder is not set, using drop_remainder = False
# 24-09-19 00:39:35 grid_pipelin INF   Including noise_indices = [0]
# 24-09-19 00:39:35 grid_pipelin INF   Interleaving with n_readers = 1
# dict_keys(['cosmo', 'i_sobol', 'i_example', 'kg', 'dg', 'cl'])
# 24-09-19 00:39:35 grid_pipelin INF   Batching into 1 elements locally
# 24-09-19 00:39:35 grid_pipelin WAR   Tracing _augmentations
# 24-09-19 00:39:35 grid_pipelin INF   Running on the data_vectors.keys() = dict_keys(['cosmo', 'i_sobol', 'i_example', 'kg', 'dg', 'cl', 'i_noise'])
# 24-09-19 00:39:35 grid_pipelin INF   Successfully generated the grid validation set with element_spec (TensorSpec(shape=(None, 460800, 8), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1536, 36), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None), (TensorSpec(shape=(None,), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None)))
# 80it [00:04, 17.33it/s]
# 80

# %%
grid_dset = grid_pipe.get_dset(
    tfr_pattern=tfr_pattern,
    noise_indices=n_noise,
    local_batch_size=batch_size,
    n_readers=1,
    n_prefetch=0,
    is_eval=True,
)

i = 0
for dv, cl, cosmo, index in grid_dset:
    print(index[1])
    i += 1
    
print(i)
# Out:
# 24-08-28 03:44:33 grid_pipelin INF   n_workers is not set, using tf.data.AUTOTUNE. This might produce unexpected RAM usage.
# 24-08-28 03:44:33 grid_pipelin INF   drop_remainder is not set, using drop_remainder = False
# 24-08-28 03:44:33 grid_pipelin INF   Including noise_indices = [0, 1, 2, 3, 4]
# 24-08-28 03:44:33 grid_pipelin INF   Interleaving with n_readers = 1
# 24-08-28 03:44:34 grid_pipelin INF   Batching into 1 elements locally
# 24-08-28 03:44:35 grid_pipelin WAR   Tracing _augmentations
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.Socket(zmq.PUSH) at 0x7ff0c3441820>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.Socket(zmq.PUSH) at 0x7ff0c3441820>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 24-08-28 03:44:36 grid_pipelin INF   Running on the data_vectors.keys() = dict_keys(['cosmo', 'cls', 'i_sobol', 'i_example', 'kg', 'dg', 'cl', 'i_noise'])
# 24-08-28 03:44:36 grid_pipelin INF   Successfully generated the grid validation set with element_spec (TensorSpec(shape=(None, 460800, 8), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1536, 36), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None), (TensorSpec(shape=(None,), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None)))
# tf.Tensor([0], shape=(1,), dtype=int64)
# tf.Tensor([0], shape=(1,), dtype=int64)
# tf.Tensor([0], shape=(1,), dtype=int64)
# tf.Tensor([0], shape=(1,), dtype=int64)
# tf.Tensor([0], shape=(1,), dtype=int64)
# tf.Tensor([1], shape=(1,), dtype=int64)
# tf.Tensor([1], shape=(1,), dtype=int64)
# tf.Tensor([1], shape=(1,), dtype=int64)
# tf.Tensor([1], shape=(1,), dtype=int64)
# tf.Tensor([1], shape=(1,), dtype=int64)
# tf.Tensor([2], shape=(1,), dtype=int64)
# tf.Tensor([2], shape=(1,), dtype=int64)
# tf.Tensor([2], shape=(1,), dtype=int64)
# tf.Tensor([2], shape=(1,), dtype=int64)
# tf.Tensor([2], shape=(1,), dtype=int64)
# tf.Tensor([3], shape=(1,), dtype=int64)
# tf.Tensor([3], shape=(1,), dtype=int64)
# tf.Tensor([3], shape=(1,), dtype=int64)
# tf.Tensor([3], shape=(1,), dtype=int64)
# tf.Tensor([3], shape=(1,), dtype=int64)
# tf.Tensor([4], shape=(1,), dtype=int64)
# tf.Tensor([4], shape=(1,), dtype=int64)
# tf.Tensor([4], shape=(1,), dtype=int64)
# tf.Tensor([4], shape=(1,), dtype=int64)
# tf.Tensor([4], shape=(1,), dtype=int64)
# tf.Tensor([5], shape=(1,), dtype=int64)
# tf.Tensor([5], shape=(1,), dtype=int64)
# tf.Tensor([5], shape=(1,), dtype=int64)
# tf.Tensor([5], shape=(1,), dtype=int64)
# tf.Tensor([5], shape=(1,), dtype=int64)
# tf.Tensor([6], shape=(1,), dtype=int64)
# tf.Tensor([6], shape=(1,), dtype=int64)
# tf.Tensor([6], shape=(1,), dtype=int64)
# tf.Tensor([6], shape=(1,), dtype=int64)
# tf.Tensor([6], shape=(1,), dtype=int64)
# tf.Tensor([7], shape=(1,), dtype=int64)
# tf.Tensor([7], shape=(1,), dtype=int64)
# tf.Tensor([7], shape=(1,), dtype=int64)
# tf.Tensor([7], shape=(1,), dtype=int64)
# tf.Tensor([7], shape=(1,), dtype=int64)
# tf.Tensor([8], shape=(1,), dtype=int64)
# tf.Tensor([8], shape=(1,), dtype=int64)
# tf.Tensor([8], shape=(1,), dtype=int64)
# tf.Tensor([8], shape=(1,), dtype=int64)
# tf.Tensor([8], shape=(1,), dtype=int64)
# tf.Tensor([9], shape=(1,), dtype=int64)
# tf.Tensor([9], shape=(1,), dtype=int64)
# tf.Tensor([9], shape=(1,), dtype=int64)
# tf.Tensor([9], shape=(1,), dtype=int64)
# tf.Tensor([9], shape=(1,), dtype=int64)
# tf.Tensor([10], shape=(1,), dtype=int64)
# tf.Tensor([10], shape=(1,), dtype=int64)
# tf.Tensor([10], shape=(1,), dtype=int64)
# tf.Tensor([10], shape=(1,), dtype=int64)
# tf.Tensor([10], shape=(1,), dtype=int64)
# tf.Tensor([11], shape=(1,), dtype=int64)
# tf.Tensor([11], shape=(1,), dtype=int64)
# tf.Tensor([11], shape=(1,), dtype=int64)
# tf.Tensor([11], shape=(1,), dtype=int64)
# tf.Tensor([11], shape=(1,), dtype=int64)
# tf.Tensor([12], shape=(1,), dtype=int64)
# tf.Tensor([12], shape=(1,), dtype=int64)
# tf.Tensor([12], shape=(1,), dtype=int64)
# tf.Tensor([12], shape=(1,), dtype=int64)
# tf.Tensor([12], shape=(1,), dtype=int64)
# tf.Tensor([13], shape=(1,), dtype=int64)
# tf.Tensor([13], shape=(1,), dtype=int64)
# tf.Tensor([13], shape=(1,), dtype=int64)
# tf.Tensor([13], shape=(1,), dtype=int64)
# tf.Tensor([13], shape=(1,), dtype=int64)
# tf.Tensor([14], shape=(1,), dtype=int64)
# tf.Tensor([14], shape=(1,), dtype=int64)
# tf.Tensor([14], shape=(1,), dtype=int64)
# tf.Tensor([14], shape=(1,), dtype=int64)
# tf.Tensor([14], shape=(1,), dtype=int64)
# tf.Tensor([15], shape=(1,), dtype=int64)
# tf.Tensor([15], shape=(1,), dtype=int64)
# tf.Tensor([15], shape=(1,), dtype=int64)
# tf.Tensor([15], shape=(1,), dtype=int64)
# tf.Tensor([15], shape=(1,), dtype=int64)
# tf.Tensor([16], shape=(1,), dtype=int64)
# tf.Tensor([16], shape=(1,), dtype=int64)
# tf.Tensor([16], shape=(1,), dtype=int64)
# tf.Tensor([16], shape=(1,), dtype=int64)
# tf.Tensor([16], shape=(1,), dtype=int64)
# tf.Tensor([17], shape=(1,), dtype=int64)
# tf.Tensor([17], shape=(1,), dtype=int64)
# tf.Tensor([17], shape=(1,), dtype=int64)
# tf.Tensor([17], shape=(1,), dtype=int64)
# tf.Tensor([17], shape=(1,), dtype=int64)
# tf.Tensor([18], shape=(1,), dtype=int64)
# tf.Tensor([18], shape=(1,), dtype=int64)
# tf.Tensor([18], shape=(1,), dtype=int64)
# tf.Tensor([18], shape=(1,), dtype=int64)
# tf.Tensor([18], shape=(1,), dtype=int64)
# tf.Tensor([19], shape=(1,), dtype=int64)
# tf.Tensor([19], shape=(1,), dtype=int64)
# tf.Tensor([19], shape=(1,), dtype=int64)
# tf.Tensor([19], shape=(1,), dtype=int64)
# tf.Tensor([19], shape=(1,), dtype=int64)
# tf.Tensor([20], shape=(1,), dtype=int64)
# tf.Tensor([20], shape=(1,), dtype=int64)
# tf.Tensor([20], shape=(1,), dtype=int64)
# tf.Tensor([20], shape=(1,), dtype=int64)
# tf.Tensor([20], shape=(1,), dtype=int64)
# tf.Tensor([21], shape=(1,), dtype=int64)
# tf.Tensor([21], shape=(1,), dtype=int64)
# tf.Tensor([21], shape=(1,), dtype=int64)
# tf.Tensor([21], shape=(1,), dtype=int64)
# tf.Tensor([21], shape=(1,), dtype=int64)
# tf.Tensor([22], shape=(1,), dtype=int64)
# tf.Tensor([22], shape=(1,), dtype=int64)
# tf.Tensor([22], shape=(1,), dtype=int64)
# tf.Tensor([22], shape=(1,), dtype=int64)
# tf.Tensor([22], shape=(1,), dtype=int64)
# tf.Tensor([23], shape=(1,), dtype=int64)
# tf.Tensor([23], shape=(1,), dtype=int64)
# tf.Tensor([23], shape=(1,), dtype=int64)
# tf.Tensor([23], shape=(1,), dtype=int64)
# tf.Tensor([23], shape=(1,), dtype=int64)
# tf.Tensor([24], shape=(1,), dtype=int64)
# tf.Tensor([24], shape=(1,), dtype=int64)
# tf.Tensor([24], shape=(1,), dtype=int64)
# tf.Tensor([24], shape=(1,), dtype=int64)
# tf.Tensor([24], shape=(1,), dtype=int64)
# tf.Tensor([25], shape=(1,), dtype=int64)
# tf.Tensor([25], shape=(1,), dtype=int64)
# tf.Tensor([25], shape=(1,), dtype=int64)
# tf.Tensor([25], shape=(1,), dtype=int64)
# tf.Tensor([25], shape=(1,), dtype=int64)
# tf.Tensor([26], shape=(1,), dtype=int64)
# tf.Tensor([26], shape=(1,), dtype=int64)
# tf.Tensor([26], shape=(1,), dtype=int64)
# tf.Tensor([26], shape=(1,), dtype=int64)
# tf.Tensor([26], shape=(1,), dtype=int64)
# tf.Tensor([27], shape=(1,), dtype=int64)
# tf.Tensor([27], shape=(1,), dtype=int64)
# tf.Tensor([27], shape=(1,), dtype=int64)
# tf.Tensor([27], shape=(1,), dtype=int64)
# tf.Tensor([27], shape=(1,), dtype=int64)
# tf.Tensor([28], shape=(1,), dtype=int64)
# tf.Tensor([28], shape=(1,), dtype=int64)
# tf.Tensor([28], shape=(1,), dtype=int64)
# tf.Tensor([28], shape=(1,), dtype=int64)
# tf.Tensor([28], shape=(1,), dtype=int64)
# tf.Tensor([29], shape=(1,), dtype=int64)
# tf.Tensor([29], shape=(1,), dtype=int64)
# tf.Tensor([29], shape=(1,), dtype=int64)
# tf.Tensor([29], shape=(1,), dtype=int64)
# tf.Tensor([29], shape=(1,), dtype=int64)
# tf.Tensor([30], shape=(1,), dtype=int64)
# tf.Tensor([30], shape=(1,), dtype=int64)
# tf.Tensor([30], shape=(1,), dtype=int64)
# tf.Tensor([30], shape=(1,), dtype=int64)
# tf.Tensor([30], shape=(1,), dtype=int64)
# tf.Tensor([31], shape=(1,), dtype=int64)
# tf.Tensor([31], shape=(1,), dtype=int64)
# tf.Tensor([31], shape=(1,), dtype=int64)
# tf.Tensor([31], shape=(1,), dtype=int64)
# tf.Tensor([31], shape=(1,), dtype=int64)
# tf.Tensor([32], shape=(1,), dtype=int64)
# tf.Tensor([32], shape=(1,), dtype=int64)
# tf.Tensor([32], shape=(1,), dtype=int64)
# tf.Tensor([32], shape=(1,), dtype=int64)
# tf.Tensor([32], shape=(1,), dtype=int64)
# tf.Tensor([33], shape=(1,), dtype=int64)
# tf.Tensor([33], shape=(1,), dtype=int64)
# tf.Tensor([33], shape=(1,), dtype=int64)
# tf.Tensor([33], shape=(1,), dtype=int64)
# tf.Tensor([33], shape=(1,), dtype=int64)
# tf.Tensor([34], shape=(1,), dtype=int64)
# tf.Tensor([34], shape=(1,), dtype=int64)
# tf.Tensor([34], shape=(1,), dtype=int64)
# tf.Tensor([34], shape=(1,), dtype=int64)
# tf.Tensor([34], shape=(1,), dtype=int64)
# tf.Tensor([35], shape=(1,), dtype=int64)
# tf.Tensor([35], shape=(1,), dtype=int64)
# tf.Tensor([35], shape=(1,), dtype=int64)
# tf.Tensor([35], shape=(1,), dtype=int64)
# tf.Tensor([35], shape=(1,), dtype=int64)
# tf.Tensor([36], shape=(1,), dtype=int64)
# tf.Tensor([36], shape=(1,), dtype=int64)
# tf.Tensor([36], shape=(1,), dtype=int64)
# tf.Tensor([36], shape=(1,), dtype=int64)
# tf.Tensor([36], shape=(1,), dtype=int64)
# tf.Tensor([37], shape=(1,), dtype=int64)
# tf.Tensor([37], shape=(1,), dtype=int64)
# tf.Tensor([37], shape=(1,), dtype=int64)
# tf.Tensor([37], shape=(1,), dtype=int64)
# tf.Tensor([37], shape=(1,), dtype=int64)
# tf.Tensor([38], shape=(1,), dtype=int64)
# tf.Tensor([38], shape=(1,), dtype=int64)
# tf.Tensor([38], shape=(1,), dtype=int64)
# tf.Tensor([38], shape=(1,), dtype=int64)
# tf.Tensor([38], shape=(1,), dtype=int64)
# tf.Tensor([39], shape=(1,), dtype=int64)
# tf.Tensor([39], shape=(1,), dtype=int64)
# tf.Tensor([39], shape=(1,), dtype=int64)
# tf.Tensor([39], shape=(1,), dtype=int64)
# tf.Tensor([39], shape=(1,), dtype=int64)
# tf.Tensor([40], shape=(1,), dtype=int64)
# tf.Tensor([40], shape=(1,), dtype=int64)
# tf.Tensor([40], shape=(1,), dtype=int64)
# tf.Tensor([40], shape=(1,), dtype=int64)
# tf.Tensor([40], shape=(1,), dtype=int64)
# tf.Tensor([41], shape=(1,), dtype=int64)
# tf.Tensor([41], shape=(1,), dtype=int64)
# tf.Tensor([41], shape=(1,), dtype=int64)
# tf.Tensor([41], shape=(1,), dtype=int64)
# tf.Tensor([41], shape=(1,), dtype=int64)
# tf.Tensor([42], shape=(1,), dtype=int64)
# tf.Tensor([42], shape=(1,), dtype=int64)
# tf.Tensor([42], shape=(1,), dtype=int64)
# tf.Tensor([42], shape=(1,), dtype=int64)
# tf.Tensor([42], shape=(1,), dtype=int64)
# tf.Tensor([43], shape=(1,), dtype=int64)
# tf.Tensor([43], shape=(1,), dtype=int64)
# tf.Tensor([43], shape=(1,), dtype=int64)
# tf.Tensor([43], shape=(1,), dtype=int64)
# tf.Tensor([43], shape=(1,), dtype=int64)
# tf.Tensor([44], shape=(1,), dtype=int64)
# tf.Tensor([44], shape=(1,), dtype=int64)
# tf.Tensor([44], shape=(1,), dtype=int64)
# tf.Tensor([44], shape=(1,), dtype=int64)
# tf.Tensor([44], shape=(1,), dtype=int64)
# tf.Tensor([45], shape=(1,), dtype=int64)
# tf.Tensor([45], shape=(1,), dtype=int64)
# tf.Tensor([45], shape=(1,), dtype=int64)
# tf.Tensor([45], shape=(1,), dtype=int64)
# tf.Tensor([45], shape=(1,), dtype=int64)
# tf.Tensor([46], shape=(1,), dtype=int64)
# tf.Tensor([46], shape=(1,), dtype=int64)
# tf.Tensor([46], shape=(1,), dtype=int64)
# tf.Tensor([46], shape=(1,), dtype=int64)
# tf.Tensor([46], shape=(1,), dtype=int64)
# tf.Tensor([47], shape=(1,), dtype=int64)
# tf.Tensor([47], shape=(1,), dtype=int64)
# tf.Tensor([47], shape=(1,), dtype=int64)
# tf.Tensor([47], shape=(1,), dtype=int64)
# tf.Tensor([47], shape=(1,), dtype=int64)
# tf.Tensor([48], shape=(1,), dtype=int64)
# tf.Tensor([48], shape=(1,), dtype=int64)
# tf.Tensor([48], shape=(1,), dtype=int64)
# tf.Tensor([48], shape=(1,), dtype=int64)
# tf.Tensor([48], shape=(1,), dtype=int64)
# tf.Tensor([49], shape=(1,), dtype=int64)
# tf.Tensor([49], shape=(1,), dtype=int64)
# tf.Tensor([49], shape=(1,), dtype=int64)
# tf.Tensor([49], shape=(1,), dtype=int64)
# tf.Tensor([49], shape=(1,), dtype=int64)
# tf.Tensor([50], shape=(1,), dtype=int64)
# tf.Tensor([50], shape=(1,), dtype=int64)
# tf.Tensor([50], shape=(1,), dtype=int64)
# tf.Tensor([50], shape=(1,), dtype=int64)
# tf.Tensor([50], shape=(1,), dtype=int64)
# tf.Tensor([51], shape=(1,), dtype=int64)
# tf.Tensor([51], shape=(1,), dtype=int64)
# tf.Tensor([51], shape=(1,), dtype=int64)
# tf.Tensor([51], shape=(1,), dtype=int64)
# tf.Tensor([51], shape=(1,), dtype=int64)
# tf.Tensor([52], shape=(1,), dtype=int64)
# tf.Tensor([52], shape=(1,), dtype=int64)
# tf.Tensor([52], shape=(1,), dtype=int64)
# tf.Tensor([52], shape=(1,), dtype=int64)
# tf.Tensor([52], shape=(1,), dtype=int64)
# tf.Tensor([53], shape=(1,), dtype=int64)
# tf.Tensor([53], shape=(1,), dtype=int64)
# tf.Tensor([53], shape=(1,), dtype=int64)
# tf.Tensor([53], shape=(1,), dtype=int64)
# tf.Tensor([53], shape=(1,), dtype=int64)
# tf.Tensor([54], shape=(1,), dtype=int64)
# tf.Tensor([54], shape=(1,), dtype=int64)
# tf.Tensor([54], shape=(1,), dtype=int64)
# tf.Tensor([54], shape=(1,), dtype=int64)
# tf.Tensor([54], shape=(1,), dtype=int64)
# tf.Tensor([55], shape=(1,), dtype=int64)
# tf.Tensor([55], shape=(1,), dtype=int64)
# tf.Tensor([55], shape=(1,), dtype=int64)
# tf.Tensor([55], shape=(1,), dtype=int64)
# tf.Tensor([55], shape=(1,), dtype=int64)
# tf.Tensor([56], shape=(1,), dtype=int64)
# tf.Tensor([56], shape=(1,), dtype=int64)
# tf.Tensor([56], shape=(1,), dtype=int64)
# tf.Tensor([56], shape=(1,), dtype=int64)
# tf.Tensor([56], shape=(1,), dtype=int64)
# tf.Tensor([57], shape=(1,), dtype=int64)
# tf.Tensor([57], shape=(1,), dtype=int64)
# tf.Tensor([57], shape=(1,), dtype=int64)
# tf.Tensor([57], shape=(1,), dtype=int64)
# tf.Tensor([57], shape=(1,), dtype=int64)
# tf.Tensor([58], shape=(1,), dtype=int64)
# tf.Tensor([58], shape=(1,), dtype=int64)
# tf.Tensor([58], shape=(1,), dtype=int64)
# tf.Tensor([58], shape=(1,), dtype=int64)
# tf.Tensor([58], shape=(1,), dtype=int64)
# tf.Tensor([59], shape=(1,), dtype=int64)
# tf.Tensor([59], shape=(1,), dtype=int64)
# tf.Tensor([59], shape=(1,), dtype=int64)
# tf.Tensor([59], shape=(1,), dtype=int64)
# tf.Tensor([59], shape=(1,), dtype=int64)
# tf.Tensor([60], shape=(1,), dtype=int64)
# tf.Tensor([60], shape=(1,), dtype=int64)
# tf.Tensor([60], shape=(1,), dtype=int64)
# tf.Tensor([60], shape=(1,), dtype=int64)
# tf.Tensor([60], shape=(1,), dtype=int64)
# tf.Tensor([61], shape=(1,), dtype=int64)
# tf.Tensor([61], shape=(1,), dtype=int64)
# tf.Tensor([61], shape=(1,), dtype=int64)
# tf.Tensor([61], shape=(1,), dtype=int64)
# tf.Tensor([61], shape=(1,), dtype=int64)
# tf.Tensor([62], shape=(1,), dtype=int64)
# tf.Tensor([62], shape=(1,), dtype=int64)
# tf.Tensor([62], shape=(1,), dtype=int64)
# tf.Tensor([62], shape=(1,), dtype=int64)
# tf.Tensor([62], shape=(1,), dtype=int64)
# tf.Tensor([63], shape=(1,), dtype=int64)
# tf.Tensor([63], shape=(1,), dtype=int64)
# tf.Tensor([63], shape=(1,), dtype=int64)
# tf.Tensor([63], shape=(1,), dtype=int64)
# tf.Tensor([63], shape=(1,), dtype=int64)
# tf.Tensor([64], shape=(1,), dtype=int64)
# tf.Tensor([64], shape=(1,), dtype=int64)
# tf.Tensor([64], shape=(1,), dtype=int64)
# tf.Tensor([64], shape=(1,), dtype=int64)
# tf.Tensor([64], shape=(1,), dtype=int64)
# tf.Tensor([65], shape=(1,), dtype=int64)
# tf.Tensor([65], shape=(1,), dtype=int64)
# tf.Tensor([65], shape=(1,), dtype=int64)
# tf.Tensor([65], shape=(1,), dtype=int64)
# tf.Tensor([65], shape=(1,), dtype=int64)
# tf.Tensor([66], shape=(1,), dtype=int64)
# tf.Tensor([66], shape=(1,), dtype=int64)
# tf.Tensor([66], shape=(1,), dtype=int64)
# tf.Tensor([66], shape=(1,), dtype=int64)
# tf.Tensor([66], shape=(1,), dtype=int64)
# tf.Tensor([67], shape=(1,), dtype=int64)
# tf.Tensor([67], shape=(1,), dtype=int64)
# tf.Tensor([67], shape=(1,), dtype=int64)
# tf.Tensor([67], shape=(1,), dtype=int64)
# tf.Tensor([67], shape=(1,), dtype=int64)
# tf.Tensor([68], shape=(1,), dtype=int64)
# tf.Tensor([68], shape=(1,), dtype=int64)
# tf.Tensor([68], shape=(1,), dtype=int64)
# tf.Tensor([68], shape=(1,), dtype=int64)
# tf.Tensor([68], shape=(1,), dtype=int64)
# tf.Tensor([69], shape=(1,), dtype=int64)
# tf.Tensor([69], shape=(1,), dtype=int64)
# tf.Tensor([69], shape=(1,), dtype=int64)
# tf.Tensor([69], shape=(1,), dtype=int64)
# tf.Tensor([69], shape=(1,), dtype=int64)
# tf.Tensor([70], shape=(1,), dtype=int64)
# tf.Tensor([70], shape=(1,), dtype=int64)
# tf.Tensor([70], shape=(1,), dtype=int64)
# tf.Tensor([70], shape=(1,), dtype=int64)
# tf.Tensor([70], shape=(1,), dtype=int64)
# tf.Tensor([71], shape=(1,), dtype=int64)
# tf.Tensor([71], shape=(1,), dtype=int64)
# tf.Tensor([71], shape=(1,), dtype=int64)
# tf.Tensor([71], shape=(1,), dtype=int64)
# tf.Tensor([71], shape=(1,), dtype=int64)
# tf.Tensor([72], shape=(1,), dtype=int64)
# tf.Tensor([72], shape=(1,), dtype=int64)
# tf.Tensor([72], shape=(1,), dtype=int64)
# tf.Tensor([72], shape=(1,), dtype=int64)
# tf.Tensor([72], shape=(1,), dtype=int64)
# tf.Tensor([73], shape=(1,), dtype=int64)
# tf.Tensor([73], shape=(1,), dtype=int64)
# tf.Tensor([73], shape=(1,), dtype=int64)
# tf.Tensor([73], shape=(1,), dtype=int64)
# tf.Tensor([73], shape=(1,), dtype=int64)
# tf.Tensor([74], shape=(1,), dtype=int64)
# tf.Tensor([74], shape=(1,), dtype=int64)
# tf.Tensor([74], shape=(1,), dtype=int64)
# tf.Tensor([74], shape=(1,), dtype=int64)
# tf.Tensor([74], shape=(1,), dtype=int64)
# tf.Tensor([75], shape=(1,), dtype=int64)
# tf.Tensor([75], shape=(1,), dtype=int64)
# tf.Tensor([75], shape=(1,), dtype=int64)
# tf.Tensor([75], shape=(1,), dtype=int64)
# tf.Tensor([75], shape=(1,), dtype=int64)
# tf.Tensor([76], shape=(1,), dtype=int64)
# tf.Tensor([76], shape=(1,), dtype=int64)
# tf.Tensor([76], shape=(1,), dtype=int64)
# tf.Tensor([76], shape=(1,), dtype=int64)
# tf.Tensor([76], shape=(1,), dtype=int64)
# tf.Tensor([77], shape=(1,), dtype=int64)
# tf.Tensor([77], shape=(1,), dtype=int64)
# tf.Tensor([77], shape=(1,), dtype=int64)
# tf.Tensor([77], shape=(1,), dtype=int64)
# tf.Tensor([77], shape=(1,), dtype=int64)
# tf.Tensor([78], shape=(1,), dtype=int64)
# tf.Tensor([78], shape=(1,), dtype=int64)
# tf.Tensor([78], shape=(1,), dtype=int64)
# tf.Tensor([78], shape=(1,), dtype=int64)
# tf.Tensor([78], shape=(1,), dtype=int64)
# tf.Tensor([79], shape=(1,), dtype=int64)
# tf.Tensor([79], shape=(1,), dtype=int64)
# tf.Tensor([79], shape=(1,), dtype=int64)
# tf.Tensor([79], shape=(1,), dtype=int64)
# tf.Tensor([79], shape=(1,), dtype=int64)
# 400

# %%
# grid_dset = grid_pipe.get_dset(
#     tfr_pattern=tfr_pattern,
#     noise_indices=n_noise,
#     local_batch_size=batch_size,
#     n_readers=1,
#     n_prefetch=0,
#     is_eval=False,
# )

# for dv, cl, cosmo, index in tqdm(grid_dset.take(n_batches), total=n_batches):
#     print(index[1])
