# %%
import numpy as np
import pickle

# %%
bias_table_file = "/pscratch/sd/j/jbucko/DESY3/mock_observations/lensing/buzzard_flock/optimal_biases_buzzard_0.pkl"
with open(bias_table_file, 'rb') as f:
    bias_table = pickle.load(f)

# %%
bias_table['cosmo_000001']
# Out:
# [1.0436462402343754,
#  1.0249191284179688,
#  1.1309263229370117,
#  1.2398437500000008]

# %%
'cosmo_000001'
# Out:
# 'cosmo_000001'

# %%
f"cosmo_{1:06}"
# Out:
# 'cosmo_000001'

# %%
bias_table.keys()
# Out:
# dict_keys(['cosmo_000001', 'cosmo_000131', 'cosmo_000279', 'cosmo_000168', 'cosmo_000039', 'cosmo_000310', 'cosmo_000251', 'cosmo_000207', 'cosmo_000271', 'cosmo_000137', 'cosmo_000003', 'cosmo_000115', 'cosmo_000194', 'cosmo_000134', 'cosmo_000004', 'cosmo_000295', 'cosmo_000118', 'cosmo_000098', 'cosmo_000091', 'cosmo_000084', 'cosmo_000174', 'cosmo_000124', 'cosmo_000214', 'cosmo_000011', 'cosmo_000178', 'cosmo_000023', 'cosmo_000199', 'cosmo_000055', 'cosmo_000200', 'cosmo_000155', 'cosmo_000284', 'cosmo_000254', 'cosmo_000176', 'cosmo_000292', 'cosmo_000148', 'cosmo_000110', 'cosmo_000238', 'cosmo_000175', 'cosmo_000307', 'cosmo_000123', 'cosmo_000230', 'cosmo_000183', 'cosmo_000047', 'cosmo_000191', 'cosmo_000082', 'cosmo_000195', 'cosmo_000132', 'cosmo_000314', 'cosmo_000140', 'cosmo_000014', 'cosmo_000019', 'cosmo_000262', 'cosmo_000202', 'cosmo_000299', 'cosmo_000142', 'cosmo_000056', 'cosmo_000158', 'cosmo_000244', 'cosmo_000302', 'cosmo_000012', 'cosmo_000126', 'cosmo_0002
# ...

# %%
temp = list(bias_table.keys())[0]

# %%
int(temp[-6:])
# Out:
# 1

# %%
i_sobol = np.array([int(key[-6:]) for key in bias_table.keys()])
i_sobol = np.sort(i_sobol)

# %%
i_sobol.max()
# Out:
# 204707

# %%
i_sobol
# Out:
# array([     1,      2,      3, ..., 204482, 204595, 204707])

# %% [markdown]
# # galaxy density

# %%
np.array([24940465, 25280405, 24891859, 25091297])/4143
# Out:
# array([6019.90465846, 6101.95631185, 6008.17258026, 6056.3111272 ])
