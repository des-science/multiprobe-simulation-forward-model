# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import healpy as hp
import h5py, os
import matplotlib.pyplot as plt
import tensorflow as tf

from msfm.grid_pipeline import GridPipeline
from msfm.fiducial_pipeline import FiducialPipeline
from msfm.utils import cross_statistics, tfrecords, files, maps, power_spectra
# Out:
# 24-01-04 16:19:42   imports.py INF   Setting up healpy to run on 8 CPUs
# 24-01-04 16:19:43   imports.py INF   Setting up healpy to run on 8 CPUs
# 24-01-04 16:19:44   imports.py INF   Setting up healpy to run on 8 CPUs

# %%
example = np.random.random_sample(1535)
bins = power_spectra.get_cl_bins(30, 1535, 33)

# %%
bins
# Out:
# array([  30.        ,   42.6462339 ,   57.51085594,   74.59386611,
#          93.89526442,  115.41505086,  139.15322544,  165.10978815,
#         193.284739  ,  223.67807799,  256.28980511,  291.11992036,
#         328.16842375,  367.43531528,  408.92059494,  452.62426274,
#         498.54631867,  546.68676274,  597.04559494,  649.62281528,
#         704.41842375,  761.43242036,  820.66480511,  882.11557799,
#         945.784739  , 1011.67228815, 1079.77822544, 1150.10255086,
#        1222.64526442, 1297.40636611, 1374.38585594, 1453.5837339 ,
#        1535.        ])

# %%
example
# Out:
# array([0.30631582, 0.8916288 , 0.34235851, ..., 0.96240178, 0.9434229 ,
#        0.54667885])
