# %%
import numpy as np
import h5py

# %%
meta_file = "/cluster/work/refregier/tomaszk/projects/220708_cosmogrid_paper/007_reshuffle_weights/v11desy3/metainfo_perms.npy"
meta_file = np.load(meta_file)

# %%
meta_file.dtype
# Out:
# dtype([('As', '<f8'), ('H0', '<f8'), ('O_cdm', '<f8'), ('O_nu', '<f8'), ('Ob', '<f8'), ('Ol', '<f8'), ('Om', '<f8'), ('bary_Mc', '<f8'), ('bary_nu', '<f8'), ('benchmark_type', '<U128'), ('box_size_Mpc_over_h', '<f8'), ('delta', '<U128'), ('id_param', '<i4'), ('m_nu', '<f8'), ('n_particles', '<i8'), ('n_shells', '<i4'), ('n_steps', '<i4'), ('ns', '<f8'), ('path_par', '<U128'), ('row_id_parslist', '<i4'), ('s8', '<f8'), ('sobol_index', '<i4'), ('w0', '<f8'), ('wa', '<f8'), ('dirname_perm', 'S512'), ('halton_point_id', '<i4'), ('id_perm', '<i4'), ('metacal1__delta_meanz', '<f4'), ('metacal1__delta_sigmaz', '<f4'), ('metacal2__delta_meanz', '<f4'), ('metacal2__delta_sigmaz', '<f4'), ('metacal3__delta_meanz', '<f4'), ('metacal3__delta_sigmaz', '<f4'), ('metacal4__delta_meanz', '<f4'), ('metacal4__delta_sigmaz', '<f4'), ('maglim1__delta_meanz', '<f4'), ('maglim1__delta_sigmaz', '<f4'), ('maglim2__delta_meanz', '<f4'), ('maglim2__delta_sigmaz', '<f4'), ('maglim3__delta_meanz', '<f4'), ('mag
# ...

# %%
fidu_meta = meta_file[meta_file["delta"] == "fiducial"]
print(fids.shape)
# Out:
# (1000,)

# %%
grid_mask = meta_file["sobol_index"] != -999
grid_meta = meta_file[grid_mask]
print(grid_meta.shape)
# Out:
# (50000,)

# %%
meta_file["metacal1__delta_sigmaz"]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
