# %%
import numpy as np
import matplotlib.pyplot as plt

import h5py, os

# %%
cardinal_dir = "/pscratch/sd/c/chto100/Cardinalv2"
catalog_file = "Cardinal-3_v2.0_Y6a_mastercat.h5"

with h5py.File(os.path.join(cardinal_dir, catalog_file), "r") as f:
    print(f.keys())
    print(f["catalog"].keys())
    print(f["index"].keys())
    
    metacal_indices = f["index/metacal/match_gold"][:]
    maglim_indices = f["index/maglim/select"][:]
# Out:
# <KeysViewHDF5 ['catalog', 'index', 'maps', 'masks', 'randoms', 'regions']>
# <KeysViewHDF5 ['bpz', 'gold', 'metacal', 'redmagic', 'redmapper']>
# <KeysViewHDF5 ['bpz', 'coadd_object_id', 'gold', 'maglim', 'mask', 'metacal', 'redmagic', 'select']>

# %%
metacal_indices.shape
# Out:
# (1397669596,)

# %%
maglim_indices.shape
# Out:
# (10832975,)
