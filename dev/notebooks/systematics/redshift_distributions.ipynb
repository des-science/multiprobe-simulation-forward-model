# %%
import numpy as np
import matplotlib.pyplot as plt

from msfm.utils import analysis

# %%
galaxy_samples = ["metacal", "maglim"]

for galaxy_sample in galaxy_samples:
    tomo_z, tomo_nz = analysis.load_redshift_distributions(galaxy_sample)

    for i, (z, nz) in enumerate(zip(tomo_z, tomo_nz)):
        print(np.sum(nz))
# Out:
# 23-04-28 17:24:54  analysis.py INF   Loaded the config
# 0.9937285860782274
# 0.9801553977560606
# 0.9758783919848851
# 0.963081013805586
# 23-04-28 17:24:54  analysis.py INF   Loaded the config
# 1.0
# 0.9999999999999999
# 0.9999999999999999
# 0.9999999999999999
# 0.9999999999999997
# 1.0
