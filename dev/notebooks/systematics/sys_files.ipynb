# %%
import h5py
import numpy as np
import healpy as hp

from msfm.utils import files

# %%
conf = files.load_config("/global/homes/a/athomsen/multiprobe-simulation-forward-model/configs/v16/default.yaml")
